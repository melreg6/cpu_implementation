# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA RTX PRO 6000 Blackwell Server Edition (UUID: GPU-df86b11b-eafa-553a-44fd-229a00c2cb19)

# %%
# %%bash
# set -e
# cd /content
# ls
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:309b05a4-0b3f-4cf7-a954-f303cc307efb
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:309b05a4-0b3f-4cf7-a954-f303cc307efb
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:309b05a4-0b3f-4cf7-a954-f303cc307efb
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:309b05a4-0b3f-4cf7-a954-f303cc307efb
# ...

# %%
# %%bash
# set -e
# cd /content/cpu_implementation_manhattan
# mkdir -p build
#
# # compile minimal (you may need to add more .c files depending on your repo)
# gcc -O3 -std=c11 -Iinclude -c src/md.c -o build/md.o
# gcc -O3 -std=c11 -Iinclude -c src/main.c -o build/main.o
#
# # link with nvcc (GPU)
# nvcc -O3 -std=c++17 -Iinclude -I/usr/local/cuda/include \
#   build/main.o build/md.o \
#   src/gpu_manhattan.cu \
#   -o build/md_run_gpu

# %%
# !cd /content/cpu_implementation_manhattan && ./build/md_run_gpu input/random_particles-1024.pdb --threads 8
